# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#import all files from \xm_API\production\cogen

dataframes_cogen = []
dataframes_hydro = []
dataframes_solar = []
dataframes_thermal = []
dataframes_wind = []

# folder_path_cogen = "\\xm_API\\production\\cogen\\"
folder_path_cogen = "C:\\Users\\thibo\\OneDrive - Hanzehogeschool Groningen\\Documenten\\Github\\thesis_UNAL\\xm_API\\production\\cogen"
folder_path_hydro = "C:\\Users\\thibo\\OneDrive - Hanzehogeschool Groningen\\Documenten\\Github\\thesis_UNAL\\xm_API\\production\\hydro"
folder_path_solar = "C:\\Users\\thibo\\OneDrive - Hanzehogeschool Groningen\\Documenten\\Github\\thesis_UNAL\\xm_API\\production\\solar"
folder_path_thermal = "C:\\Users\\thibo\\OneDrive - Hanzehogeschool Groningen\\Documenten\\Github\\thesis_UNAL\\xm_API\\production\\thermal"
folder_path_wind = "C:\\Users\\thibo\\OneDrive - Hanzehogeschool Groningen\\Documenten\\Github\\thesis_UNAL\\xm_API\\production\\wind"

# for filename in os.listdir(folder_path_cogen):
#     if filename.endswith('.csv'):
#         file_path = os.path.join(folder_path_cogen, filename)
#         df = pd.read_csv(file_path)
#         dataframes_cogen.append(df)
# cogen = pd.concat(dataframes_cogen, ignore_index=True)
# cogen['Timestamp'] = pd.to_datetime(cogen['Timestamp'])
# cogen = cogen.sort_values(by=['Timestamp'])
# cogen = cogen.set_index('Timestamp')

for filename in os.listdir(folder_path_hydro):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path_hydro, filename)
        df = pd.read_csv(file_path)
        dataframes_hydro.append(df)
hydro = pd.concat(dataframes_hydro, ignore_index=True)
hydro['Timestamp'] = pd.to_datetime(hydro['Timestamp'])
hydro = hydro.sort_values(by=['Timestamp'])
hydro = hydro.set_index('Timestamp')

# for filename in os.listdir(folder_path_solar):
#     if filename.endswith('.csv'):
#         file_path = os.path.join(folder_path_solar, filename)
#         df = pd.read_csv(file_path)
#         dataframes_solar.append(df)
# solar = pd.concat(dataframes_solar, ignore_index=True)
# solar['Timestamp'] = pd.to_datetime(solar['Timestamp'])
# solar = solar.sort_values(by=['Timestamp'])
# solar = solar.set_index('Timestamp')

# for filename in os.listdir(folder_path_thermal):
#     if filename.endswith('.csv'):
#         file_path = os.path.join(folder_path_thermal, filename)
#         df = pd.read_csv(file_path)
#         dataframes_thermal.append(df)
# thermal = pd.concat(dataframes_thermal, ignore_index=True)
# thermal['Timestamp'] = pd.to_datetime(thermal['Timestamp'])
# thermal = thermal.sort_values(by=['Timestamp'])
# thermal = thermal.set_index('Timestamp')

# for filename in os.listdir(folder_path_wind):
#     if filename.endswith('.csv'):
#         file_path = os.path.join(folder_path_wind, filename)
#         df = pd.read_csv(file_path)
#         dataframes_wind.append(df)
# wind = pd.concat(dataframes_wind, ignore_index=True)
# wind['Timestamp'] = pd.to_datetime(wind['Timestamp'])
# wind = wind.sort_values(by=['Timestamp'])
# wind = wind.set_index('Timestamp')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23000/227320969.py in <module>
#      27     if filename.endswith('.csv'):
#      28         file_path = os.path.join(folder_path_hydro, filename)
# ---> 29         df = pd.read_csv(file_path)
#      30         dataframes_hydro.append(df)
#      31 hydro = pd.concat(dataframes_hydro, ignore_index=True)
#
# c:\Users\thibo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# plt.plot(cogen.index, cogen['Total[kW]'])
# plt.title('Cogen')
# plt.show()

plt.plot(hydro.index, hydro['Total[kW]'])
plt.title('Hydro')
plt.show()

# plt.plot(solar.index, solar['Total[kW]'])
# plt.title('Solar')
# plt.show()

# plt.plot(thermal.index, thermal['Total[kW]'])
# plt.title('Thermal')
# plt.show()

# plt.plot(wind.index, wind['Total[kW]'])
# plt.title('Wind')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23000/2411140537.py in <module>
#       7 plt.show()
#       8
# ----> 9 plt.plot(solar.index, solar['Total[kW]'])
#      10 plt.title('Solar')
#      11 plt.show()
#
# NameError: name 'solar' is not defined
