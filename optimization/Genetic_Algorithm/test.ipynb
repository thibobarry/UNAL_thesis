# %%
from pydataxm import *                          
import datetime as dt
import pandas as pd
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
#show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#make columns wider
pd.set_option('display.max_colwidth', None)
#stop warnings
import warnings
warnings.filterwarnings('ignore')
objetoAPI = pydataxm.ReadDB()  

df = objetoAPI.get_collections()
#filter where Entity is 'Recurso'
df = df[df['Entity'] == 'Recurso']


# df_plant = objetoAPI.request_data(
#                 "Gene",           
#                 "Recurso",             
#                 dt.date(2022, 1, 1),  
#                 dt.date(2022, 1, 31))
# df_plant.head()
df
# Out:
#                 MetricId  \
# 8    ConsCombustibleMBTU
# 9                   Gene
# 10         IndRecMargina
# 12          PrecOferDesp
# 20              GeneIdea
# 25        EmisionesCO2Eq
# 34         GeneSeguridad
# 35       GeneFueraMerito
# 37          GeneProgDesp
# 38        GeneProgRedesp
# 39             DispoReal
# 40             DispoCome
# 41        DispoDeclarada
# 42           RecoPosEner
# 43           RecoNegEner
# 45              DesvEner
# 46            DesvMoneda
# 47         RecoPosMoneda
# 48         RecoNegMoneda
# 113               ENFICC
# 123          CapEfecNeta
# 128       ObligEnerFirme
# 137        DDVContratada
# 139      ComContRespEner
# 140         PrecCargConf
# 141     VentContRespEner
# 155        PrecOferIdeal
# 162             IrrPanel
# 163            IrrGlobal
# 164            TempPanel
# 165         TempAmbSolar
#
#                                                         MetricName   Entity  \
# ...

# %%
df_plant = objetoAPI.request_data(
                "Gene",           
                "Recurso",             
                dt.date(2022, 1, 1),  
                dt.date(2022, 1, 31))
df_plant.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/1156563101.py in <module>
# ----> 1 df_plant = objetoAPI.request_data(
#       2                 "Gene",
#       3                 "Recurso",
#       4                 dt.date(2022, 1, 1),
#       5                 dt.date(2022, 1, 31))
#
# c:\Users\thibo\AppData\Local\Programs\Python\Python39\lib\site-packages\pydataxm\pydataxm.py in request_data(self, coleccion, metrica, start_date, end_date, filtros)
#     114                     data = temporal_data.copy()
#     115                 else:
# --> 116                     data = data.append(temporal_data, ignore_index=True)
#     117                 start_date = start_date + dt.timedelta(30)
#     118
#
# c:\Users\thibo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5987         ):
# ...

# %%
frames = []

# Loop through your date ranges and request data
current_date = dt.date(2022, 1, 1)
end_date = dt.date(2022, 1, 31)
while current_date <= end_date:
    df_plant = objetoAPI.request_data("Gene", "Recurso", current_date, current_date)
    frames.append(df_plant)
    current_date += dt.timedelta(days=1)

# Concatenate the list of DataFrames into a single DataFrame
merged_df = pd.concat(frames, ignore_index=True)

# %%
merged_df.head()
# Out:
#         Id Values_code  Values_Hour01  Values_Hour02  Values_Hour03  \
# 0  Recurso        2QBW       19938.73       19929.12       19884.45
# 1  Recurso        2QRL         678.39         678.18         620.58
# 2  Recurso        2R22            NaN            NaN            NaN
# 3  Recurso        2S6S           2.40            NaN            NaN
# 4  Recurso        2S6U        6664.52        6661.22        6690.75
#
#    Values_Hour04  Values_Hour05  Values_Hour06  Values_Hour07  Values_Hour08  \
# 0       19501.63       19813.54       19807.26       19870.91       18072.15
# 1         678.90         678.27         679.35         678.99         679.20
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4        6693.23        6691.25        5703.89        6080.91        6668.31
#
#    Values_Hour09  Values_Hour10  Values_Hour11  Values_Hour12  Values_Hour13  \
# ...
